# %% [markdown]
# <a href="https://colab.research.google.com/github/niltontac/EspAnalise-EngDados/blob/master/Covid_19_Analysis_and_Predictions%20-%20In%20Progress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Sobre este conjunto de dados
#
# #####Estes conjuntos de dados fornecidos da Johns Hopkins University possui informações com atualizações diárias sobre os números de casos confirmados, de mortes e de recuperação do Covid-19. Observe que esses são dados de séries temporais e, portando, os números de casos em um determinado dia são números acumulados.
#
#
# #About this Dataset
#
# #####These data sets provides from Johns Hopkins University have information with daily updates on the numbers of confirmed cases, deaths and recovery from Covid-19. Note that these are data from time series and the numbers of cases on a given day are cumulative numbers.
#
# ---
#
# #####Fonte | Source (Datasets):
# ##### https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_time_series
# ##### https://github.com/niltontac/EspAnalise-EngDados/tree/master/data/Novel_Corona_Virus_2019_Dataset
#
# ---
#
# #####Analyst: Nilton Thiago de Andrade Coura

# %% [markdown]
# # Covid-19 - Exploratory Analysis and Predictions
#
# ![alt text](https://cdn.cnn.com/cnnnext/dam/assets/200130165125-corona-virus-cdc-image-super-tease.jpg)

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from datetime import date

# Loading dataset
# Last dataset update 03/27/2020

covid19confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

covid19deaths = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')

covid19recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

covid19 = pd.read_csv('https://raw.githubusercontent.com/niltontac/EspAnalise-EngDados/master/data/Novel_Corona_Virus_2019_Dataset/covid_19_data.csv', parse_dates=['ObservationDate', 'Last Update'])

# %%
last_date_update = '3/28/20'

# %% [markdown]
# Checking the last 5 cases to confirm when all the data sets were updated:

# %%
print('covid19confirmed:')
print(covid19confirmed.tail())
####
print('covid19deaths:')
print(covid19deaths.tail())
####
print('covid19recovered:')
print(covid19recovered.tail())
####
print('covid19:')
print(covid19.tail())
# Out:
# covid19confirmed:
#                Province/State  Country/Region  ...  3/27/20  3/28/20
# 248                       NaN           Burma  ...        8        8
# 249                  Anguilla  United Kingdom  ...        0        2
# 250    British Virgin Islands  United Kingdom  ...        0        2
# 251  Turks and Caicos Islands  United Kingdom  ...        0        4
# 252                       NaN      MS Zaandam  ...        0        2
#
# [5 rows x 71 columns]
# covid19deaths:
#                Province/State  Country/Region  ...  3/27/20  3/28/20
# 248                       NaN           Burma  ...        0        0
# 249                  Anguilla  United Kingdom  ...        0        0
# 250    British Virgin Islands  United Kingdom  ...        0        0
# 251  Turks and Caicos Islands  United Kingdom  ...        0        0
# 252                       NaN      MS Zaandam  ...        0        0
#
# [5 rows x 71 columns]
# covid19recovered:
#                Province/State  Country/Region  ...  3/27/20  3/28/20
# 234                       NaN           Burma  ...        0        0
# 235                  Anguilla  United Kingdom  ...        0        0
# 236    British Virgin Islands  United Kingdom  ...        0        0
# 237  Turks and Caicos Islands  United Kingdom  ...        0        0
# 238                       NaN      MS Zaandam  ...        0        0
#
# [5 rows x 71 columns]
# covid19:
#        SNo ObservationDate Province/State  ... Confirmed Deaths  Recovered
# 9730  9731      2020-03-28        Wyoming  ...      82.0    0.0        0.0
# 9731  9732      2020-03-28       Xinjiang  ...      76.0    3.0       73.0
# 9732  9733      2020-03-28          Yukon  ...       4.0    0.0        0.0
# 9733  9734      2020-03-28         Yunnan  ...     180.0    2.0      172.0
# 9734  9735      2020-03-28       Zhejiang  ...    1251.0    1.0     1225.0
#
# [5 rows x 8 columns]

# %% [markdown]
# Dimension of data sets (rows vs columns):

# %%
print('covid19confirmed:')
print(covid19confirmed.shape)
####
print('covid19deaths:')
print(covid19deaths.shape)
####
print('covid19recovered:')
print(covid19recovered.shape)
####
print('covid19:')
print(covid19.shape)
# Out:
# covid19confirmed:
# (253, 71)
# covid19deaths:
# (253, 71)
# covid19recovered:
# (239, 71)
# covid19:
# (9735, 8)

# %% [markdown]
# Checking for null or missing values:

# %%
print('covid19confirmed:')
print(pd.DataFrame(covid19confirmed.isnull().sum()))
####
print('covid19deaths:')
print(pd.DataFrame(covid19deaths.isnull().sum()))
####
print('covid19recovered:')
print(pd.DataFrame(covid19recovered.isnull().sum()))
####
print('covid19:')
print(pd.DataFrame(covid19.isnull().sum()))
# Out:
# covid19confirmed:
#                   0
# Province/State  174
# Country/Region    0
# Lat               0
# Long              0
# 1/22/20           0
# ...             ...
# 3/24/20           0
# 3/25/20           0
# 3/26/20           0
# 3/27/20           0
# 3/28/20           0
#
# [71 rows x 1 columns]
# covid19deaths:
#                   0
# Province/State  174
# Country/Region    0
# Lat               0
# Long              0
# 1/22/20           0
# ...             ...
# 3/24/20           0
# 3/25/20           0
# 3/26/20           0
# 3/27/20           0
# 3/28/20           0
#
# [71 rows x 1 columns]
# covid19recovered:
#                   0
# Province/State  175
# Country/Region    0
# Lat               0
# Long              0
# 1/22/20           0
# ...             ...
# 3/24/20           0
# 3/25/20           0
# 3/26/20           0
# 3/27/20           0
# 3/28/20           0
#
# [71 rows x 1 columns]
# covid19:
#                     0
# SNo                 0
# ObservationDate     0
# Province/State   4433
# Country/Region      0
# Last Update         0
# Confirmed           0
# Deaths              0
# Recovered           0

# %% [markdown]
# The data sets have missings values or null in "Province/State" column.
# Let's replace them with 'unknow':

# %%
# Replacing data missings

covid19confirmed = covid19confirmed.fillna('unknow')
covid19deaths = covid19deaths.fillna('unknow')
covid19recovered = covid19recovered.fillna('unknow')
covid19 = covid19.fillna('unknow')

# %%
# Checking for null or missing values again

print('covid19confirmed:')
print(pd.DataFrame(covid19confirmed.isnull().sum()))
####
print('covid19deaths:')
print(pd.DataFrame(covid19deaths.isnull().sum()))
####
print('covid19recovered:')
print(pd.DataFrame(covid19recovered.isnull().sum()))
####
print('covid19:')
print(pd.DataFrame(covid19.isnull().sum()))
# Out:
# covid19confirmed:
#                 0
# Province/State  0
# Country/Region  0
# Lat             0
# Long            0
# 1/22/20         0
# ...            ..
# 3/24/20         0
# 3/25/20         0
# 3/26/20         0
# 3/27/20         0
# 3/28/20         0
#
# [71 rows x 1 columns]
# covid19deaths:
#                 0
# Province/State  0
# Country/Region  0
# Lat             0
# Long            0
# 1/22/20         0
# ...            ..
# 3/24/20         0
# 3/25/20         0
# 3/26/20         0
# 3/27/20         0
# 3/28/20         0
#
# [71 rows x 1 columns]
# covid19recovered:
#                 0
# Province/State  0
# Country/Region  0
# Lat             0
# Long            0
# 1/22/20         0
# ...            ..
# 3/24/20         0
# 3/25/20         0
# 3/26/20         0
# 3/27/20         0
# 3/28/20         0
#
# [71 rows x 1 columns]
# covid19:
#                  0
# SNo              0
# ObservationDate  0
# Province/State   0
# Country/Region   0
# Last Update      0
# Confirmed        0
# Deaths           0
# Recovered        0

# %% [markdown]
# #Plotly Visualizations:

# %% [markdown]
# All records including confirmed cases, deaths and recovered:

# %%
# all confirmed, deaths and recovered cases

case_growth = covid19.groupby('ObservationDate')['Confirmed', 'Deaths', 'Recovered'].sum()
case_growth = case_growth.reset_index()
case_growth = case_growth.sort_values('ObservationDate', ascending=False)

fig = go.Figure()
fig.update_layout(template='plotly_dark')

fig.add_trace(go.Scatter(x=case_growth['ObservationDate'], 
                        y=case_growth['Confirmed'], 
                        mode='lines+markers',
                        name='Confirmed',
                        line=dict(color='Yellow', width=2)))

fig.add_trace(go.Scatter(x=case_growth['ObservationDate'], 
                        y=case_growth['Deaths'], 
                        mode='lines+markers',
                        name='Deaths',
                        line=dict(color='red', width=2)))

fig.add_trace(go.Scatter(x=case_growth['ObservationDate'], 
                        y=case_growth['Recovered'], 
                        mode='lines+markers',
                        name='Recovered',
                        line=dict(color='green', width=2)))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b83c32d4-f7c9-4d2e-99e7-026f571e79c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b83c32d4-f7c9-4d2e-99e7-026f571e79c0")) {
#                     Plotly.newPlot(
#                         'b83c32d4-f7c9-4d2e-99e7-026f571e79c0',
#                         [{"line": {"color": "Yellow", "width": 2}, "mode": "lines+markers", "name": "Confirmed", "type": "scatter", "x": ["2020-03-28T00:00:00", "2020-03-27T00:00:00", "2020-03-26T00:00:00", "2020-03-25T00:00:00", "2020-03-24T00:00:00", "2020-03-23T00:00:00", "2020-03-22T00:00:00", "2020-03-21T00:00:00", "2020-03-20T00:00:00", "2020-03-19T00:00:00", "2020-03-18T00:00:00", "2020-03-17T00:00:00", "2020-03-16T00:00:00", "2020-03-15T00:00:00", "2020-03-14T00:00:00", "2020-03-13T00:00:00", "2020-03-12T00:00:00", "2020-03-11T00:00:00", "2020-03-10T00:00:00", "2020-03-09T00:00:00", "2020-03-08T00:00:00", "2020-03-07T00:00:00", "2020-03-06T00:00:00", "2020-03-05T00:00:00", "2020-03-04T00:00:00", "2020-03-03T00:00:00", "2020-03-02T00:00:00", "2020-03-01T00:00:00", "2020-02-29T00:00:00", "2020-02-28T00:00:00", "2020-02-27T00:00:00", "2020-02-26T00:00:00", "2020-02-25T00:00:00", "2020-02-24T00:00:00", "2020-02-23T00:00:00", "2020-02-22T00:00:00", "2020-02-21T00:00:00", "2020-02-20T00:00:00", "2020-02-19T00:00:00", "2020-02-18T00:00:00", "2020-02-17T00:00:00", "2020-02-16T00:00:00", "2020-02-15T00:00:00", "2020-02-
00:00", "2020-02-06T00:00:00", "2020-02-05T00:00:00", "2020-02-04T00:00:00", "2020-02-03T00:00:00", "2020-02-02T00:00:00", "2020-02-01T00:00:00", "2020-01-31T00:00:00", "2020-01-30T00:00:00", "2020-01-29T00:00:00", "2020-01-28T00:00:00", "2020-01-27T00:00:00", "2020-01-26T00:00:00", "2020-01-25T00:00:00", "2020-01-24T00:00:00", "2020-01-23T00:00:00", "2020-01-22T00:00:00"], "y": [30652.0, 27198.0, 23970.0, 21181.0, 18615.0, ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506

# %% [markdown]
# Confirmed cases, Deaths and Recovered in all affected countries around the world:

# %%
cases_temp = covid19confirmed 
cases_temp = cases_temp[['Country/Region', last_date_update]]
cases_temp = cases_temp.groupby('Country/Region').sum().sort_values(by = last_date_update,ascending = False)
cases_temp['Recovered'] = covid19recovered[['Country/Region', last_date_update]].groupby('Country/Region').sum().sort_values(by = last_date_update, ascending = False)
cases_temp['Deaths'] = covid19deaths[['Country/Region', last_date_update]].groupby('Country/Region').sum().sort_values(by = last_date_update, ascending = False)
cases_temp['Non_recovered'] = cases_temp[last_date_update] - cases_temp['Recovered'] - cases_temp['Deaths']
cases_temp = cases_temp.rename(columns = {last_date_update: 'Confirmed', 'Recovered' : 'Recovered', 'Deaths' : 'Deaths', 'Non_recovered' : 'Non_recovered'})

cases_temp.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row0_col1 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row0_col2 {
#             background-color:  #fdcab5;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row0_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row1_col0 {
#             background-color:  #c8171c;
#             color:  #f1f1f1;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row1_col1 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row1_col3 {
#             background-color:  #f24734;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row2_col0 {
#             background-color:  #e12d26;
#             color:  #f1f1f1;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row2_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row2_col2 {
#             background-color:  #fca183;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row2_col3 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row3_col0 {
#             background-color:  #f14331;
#             color:  #f1f1f1;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row3_col1 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row3_col2 {
#             background-color:  #f24633;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row3_col3 {
#             background-color:  #fb7656;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row4_col0 {
#             background-color:  #fb7252;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row4_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row4_col2 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row4_col3 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row5_col0 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row5_col1 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row5_col2 {
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row5_col3 {
#             background-color:  #fcb99f;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row6_col0 {
#             background-color:  #fcae92;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row6_col1 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row6_col2 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row6_col3 {
#             background-color:  #fdd1be;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row7_col0 {
#             background-color:  #fedbcc;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row7_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row7_col2 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row7_col3 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row8_col0 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row8_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row8_col2 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row8_col3 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row9_col0 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row9_col2 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row9_col3 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row10_col0 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row10_col1 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row10_col2 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row10_col3 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row11_col0 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row11_col1 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row11_col2 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row11_col3 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row12_col0 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row12_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row12_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row12_col3 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row13_col0 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row13_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row13_col2 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row13_col3 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row14_col0 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row14_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row14_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_0a7c1734_720c_11ea_ad46_0242ac1c0002row14_col3 {
#             background-color:  #ffeee7;

# %% [markdown]
# report in progress for the next few days...
